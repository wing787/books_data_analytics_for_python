# %% [markdown]
# ## 4.4.4 次元削減

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 主成分分析

# %%
# シード値を固定
rng = np.random.RandomState(123)
# 0以上1未満の一様乱数を50個生成
X = rng.uniform(size=50)
# Xを2倍にした後に、0以上1未満の一様乱数を0.5倍して足し合わせる
Y = 2*X + 0.5*rng.uniform(size=50)
# 散布図をプロット
fig, ax = plt.subplots()
ax.scatter(X, Y)
plt.show()

# %%
from sklearn.decomposition import PCA


# 主成分のクラスをインスタンス化
pca = PCA(n_components=2)
# 主成分分析を実行
X_pca = pca.fit_transform(np.hstack((X.reshape(-1, 1), Y.reshape(-1, 1))))

# %%
# 主成分分析の結果、得られた座標を散布図にプロット
fig, ax = plt.subplots()
ax.scatter(X_pca[:, 0], X_pca[:, 1])
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_xlim(-1.1, 1.1)
ax.set_ylim(-1.1, 1.1)
plt.show()
